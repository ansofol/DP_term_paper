# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np 
from matplotlib import pyplot as plt 

from model import study_model
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = study_model()

# %%
model.solve()

# %%
sol = model.sol

plt.plot(sol.m[5,1,3,:],sol.c[8,1,3,:])
plt.plot(sol.m[5,1,3,:],sol.c[5,1,3,:])
plt.plot(sol.m[5,1,3,:],sol.c[0,1,3,:])
