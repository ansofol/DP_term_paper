# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np 
from model import Model
from EGM_Study_Stage import marg_u 
from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = Model()
model.setup()
model.set_grids()

# %%
model.solve()
sol = model.sol
par = model.par
# Out:
# c:\Users\Mathias\Desktop\DP_term_paper\EGM study - development\EGM_Study_Stage.py:174: RuntimeWarning: divide by zero encountered in power
#   return c**(-par.rho)
# c:\Users\Mathias\Desktop\DP_term_paper\EGM study - development\EGM_Study_Stage.py:168: RuntimeWarning: divide by zero encountered in reciprocal
#   return c**(1-par.rho)/(1-par.rho)

# %%
#plt.plot(sol.c[0,3,1,3,:,4])
#plt.plot(sol.c[0,3,1,3,:,0])
plt.plot(sol.V[0,3,0,3,par.Ba:,0])

# %%
par.eps_grid
# Out:
# array([-2.02018287e+00, -9.58572465e-01,  1.71930592e-16,  9.58572465e-01,
#         2.02018287e+00])

# %%
sol.c[0,3,1,3,:,0]
# Out:
# array([1.00000000e-16, 2.24464763e-01, 4.48929527e-01, 6.73394290e-01,
#        8.97859054e-01, 1.12232382e+00, 1.34678858e+00, 1.57125334e+00,
#        1.79571811e+00, 2.02018287e+00, 1.47444676e-16, 3.30020788e-02,
#        3.96942447e-02, 7.38939092e-03, 2.91895967e-02, 4.69870643e-02,
#        1.98409434e-02, 3.33318582e-02, 5.82275727e-02, 4.63569818e-02,
#        5.15190154e-02, 7.96979556e-02, 9.29258106e-02, 9.48963273e-02,
#        1.21469809e-01, 1.48944403e-01, 1.68268162e-01, 1.91924636e-01,
#        2.20726973e-01, 2.48864721e-01, 2.76831724e-01, 3.04343329e-01,
#        3.30345057e-01, 3.56861660e-01, 3.82302063e-01, 4.05928253e-01,
#        4.29027091e-01, 4.51469028e-01, 4.73224408e-01, 4.94542921e-01,
#        5.15560193e-01, 5.36327711e-01, 5.56921913e-01, 5.77406540e-01,
#        5.97816144e-01, 6.18175562e-01, 6.38505534e-01, 6.58821440e-01,
#        6.79132478e-01, 6.99447922e-01, 7.19775910e-01, 7.40121849e-01,
# ...
