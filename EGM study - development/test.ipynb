# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np 
from model import Model
from EGM_Study_Stage import marg_u 
from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = Model()
model.setup()
model.set_grids()

# %%
model.solve()

# %%
sol = model.sol

# %%
plt.plot(sol.c[0,2,1,2,:,0])
plt.plot(sol.c[0,2,0,2,:,0]);

# %%
model = Model()
model.setup()
model.set_grids()
model.solve()
sol = model.sol
plt.plot(sol.c[0,2,1,2,:,0])
plt.plot(sol.c[0,2,0,2,:,0]);

# %%
assert np.mean(np.isnan(sol.m[0,2,0,2,:,0])) ==0
