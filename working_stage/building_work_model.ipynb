# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from working_model import WorkModel
from scipy import optimize
import EGM 
import tools

from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = WorkModel()

model.setup()

model.par.Na = 100
model.par.Ntypes = 1
model.par.Tmax = 5
model.par.Smax = 2
model.par.a_min = 0
model.par.a_max = 10

model.set_grids()

par = model.par
sol = model.sol

# %%
model.solve()
# Out:
# c:\Users\sofie\OneDrive\Dokumenter\Skole\DynamicProgramming\DP_term_paper\working_stage\working_model.py:109: RuntimeWarning: divide by zero encountered in double_scalars
#   return (c**(1-par.rho))/(1-par.rho) - (ell**(1+par.nu))/(1+par.nu) - penalty

# %%
t = -1
plt.plot(par.a_grid, sol.c[0,t,1,0,par.Ba:,0],  label='c_t')
plt.plot(par.a_grid, sol.ell[0,t,1, 0,par.Ba:,0], label='l_t')
plt.legend()
# seems about right

# %%
# plot some policy functions, just to be sure
t = 2
edu = 0
type = 0 

fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(1,3,1)
ax.plot(par.a_grid, sol.c[type, t, 1, edu, par.Ba:, 4], label='i_eps=4')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, par.Ba:, 3], label='i_eps=3')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, par.Ba:, 2], label='i_eps=2')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, par.Ba:, 1], label='i_eps=1')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, par.Ba:, 0], label='i_eps=0')
ax.set_title('consumption')
ax.legend()

ax = fig.add_subplot(1,3,2)
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, par.Ba:, 4])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, par.Ba:, 3])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, par.Ba:, 2])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, par.Ba:, 1])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, par.Ba:, 0])
ax.set_title('labor supply')

ax = fig.add_subplot(1,3,3)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, par.Ba:, 4]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, par.Ba:, 3]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, par.Ba:, 2]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, par.Ba:, 1]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, par.Ba:, 0]-par.a_grid)
ax.set_title('Savings')
# Out:
# Text(0.5, 1.0, 'Savings')
