# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from working_model import WorkModel
from scipy import optimize
import EGM 
import tools

from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = WorkModel()

model.setup()

model.par.Na = 100
model.par.Ntypes = 1
model.par.Tmax = 45
model.par.Smax = 2
model.par.a_min = 0
model.par.a_max = 500

model.set_grids()


par = model.par
sol = model.sol

# %%
model.solve()

# %%
model.sol.V[0, 0, 1, 0]
# Out:
# array([[nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan],
# ...

# %%
t = 20
plt.plot(par.a_grid, sol.c[0,t,1,0,:,0],  label='c_t')
plt.plot(par.a_grid, sol.ell[0,t,1, 0,:,0], label='l_t')
plt.legend()
# seems about right

# %%
# plot some policy functions, just to be sure
t = 20
edu = 0
type = 0 

fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(1,3,1)
ax.plot(par.a_grid, sol.c[type, t, 1, edu, :, 4], label='i_eps=4')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, :, 3], label='i_eps=3')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, :, 2], label='i_eps=2')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, :, 1], label='i_eps=1')
ax.plot(par.a_grid, sol.c[type, t, 1, edu, :, 0], label='i_eps=0')
ax.set_title('consumption')
ax.legend()

ax = fig.add_subplot(1,3,2)
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, :, 4])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, :, 3])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, :, 2])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, :, 1])
ax.plot(par.a_grid, sol.ell[type, t, 1, edu, :, 0])
ax.set_title('labor supply')

ax = fig.add_subplot(1,3,3)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, :, 4]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, :, 3]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, :, 2]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, :, 1]-par.a_grid)
ax.plot(par.a_grid, sol.a[type, t, 1, edu, :, 0]-par.a_grid)
ax.set_title('Savings')
# Out:
# Text(0.5, 1.0, 'Savings')
